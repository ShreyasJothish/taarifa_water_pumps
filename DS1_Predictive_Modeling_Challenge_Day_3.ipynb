# %% [markdown]
# <a href="https://colab.research.google.com/github/ShreyasJothish/taarifa_water_pumps/blob/master/DS1_Predictive_Modeling_Challenge_Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the data from Kaggle
# !pip install kaggle

# Upgrade the version of Seaborn
# !pip install -U seaborn

# Install category_encoders
# !pip install category_encoders
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.6/dist-packages (1.5.2)
# Requirement already satisfied: urllib3<1.23.0,>=1.15 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.22)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.6/dist-packages (from kaggle) (1.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from kaggle) (2018.11.29)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.5.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.18.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from kaggle) (4.28.1)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.6/dist-packages (from kaggle) (2.0.1)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: Unidecode>=0.04.16 in /usr/local/lib/python3.6/dist-packages (from python-slugify->kaggle) (1.0.23)
# Requirement already up-to-date: seaborn in /usr/local/lib/python3.6/dist-packages (0.9.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.3 in /usr/local/lib/python3.6/dist-packages (from seaborn) (1.14.6)
# Requirement already satisfied, skipping upgrade: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from seaborn) (1.1.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.15.2 in /usr/local/lib/python3.6/dist-packages (from seaborn) (0.22.0)
# Requirement already satisfied, skipping upgrade: matplotlib>=1.4.3 in /usr/local/lib/python3.6/dist-packages (from seaborn) (3.0.2)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.15.2->seaborn) (2018.9)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.15.2->seaborn) (2.5.3)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=1.4.3->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=1.4.3->seaborn) (2.3.1)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=1.4.3->seaborn) (1.0.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2->pandas>=0.15.2->seaborn) (1.11.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from kiwisolver>=1.0.1->matplotlib>=1.4.3->seaborn) (40.7.3)
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.6/dist-packages (1.3.0)
# Requirement already satisfied: statsmodels>=0.6.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.8.0)
# Requirement already satisfied: pandas>=0.20.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.22.0)
# Requirement already satisfied: scikit-learn>=0.17.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.20.2)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.14.6)
# Requirement already satisfied: patsy>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.1.0)
# Requirement already satisfied: python-dateutil>=2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.1->category_encoders) (2.5.3)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.20.1->category_encoders) (2018.9)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.4.1->category_encoders) (1.11.0)

# %%
# Mount the drive to download the data from Kaggle
from google.colab import drive
drive.mount('/content/drive')
# %env KAGGLE_CONFIG_DIR=/content/drive/My Drive

# !kaggle competitions download -c ds1-predictive-modeling-challenge
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# env: KAGGLE_CONFIG_DIR=/content/drive/My Drive
# sample_submission.csv: Skipping, found more recently modified local copy (use --force to force download)
# test_features.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train_labels.csv.zip: Skipping, found more recently modified local copy (use --force to force download)
# train_features.csv.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# Extract the csv files
# !unzip train_features.csv.zip 
# !unzip train_labels.csv.zip 
# !unzip test_features.csv.zip
# Out:
# Archive:  train_features.csv.zip
# replace train_features.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Archive:  train_labels.csv.zip
# replace train_labels.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N
# Archive:  test_features.csv.zip
# replace test_features.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
# Generic imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the independent features as X and
# dependent variable as y
nan_values_list = ['Not Known', 'Unknown', 'None', 'Not known', 'not known', 
                   '-', 'unknown', 'Unknown Installer', '##', 'none']

train_features_df = pd.read_csv('train_features.csv', na_values=nan_values_list)
train_labels_df = pd.read_csv('train_labels.csv')

# %%
"""# Test Code to be removed later
train_features_df = train_features_df.sample(5000, random_state=42)
train_labels_df = train_labels_df.sample(5000, random_state=42)
train_labels_df.status_group.value_counts()"""
# Out:
# '# Test Code to be removed later\ntrain_features_df = train_features_df.sample(5000, random_state=42)\ntrain_labels_df = train_labels_df.sample(5000, random_state=42)\ntrain_labels_df.status_group.value_counts()'

# %%
def atleast(row, value_count_series, count=5):
  # Identify items who have funded atleast 5 pumps
  if str(row) == "nan":
    return np.nan
  
  value_count = value_count_series.get(row)
  
  if value_count < count:
    return 0
  else:
    return 1

def character_grouping(row):
  # Reduce the dimension based on 1st character else return *
  if str(row) == "nan":
    return np.nan
  
  if row[0].isalpha():
    return row[0].lower()
  else:
    return "*"
  
def classify_lga(row):
  # Classify lga into Rural, Urban and others
  if str(row) == "nan":
    return np.nan
  
  if row.lower().find('rural'):
    return "rural"
  elif row.lower().find('urban'):
    return "urban"
  else:
    return "other"
  
def prefix_grouping(row, prefix_count=3):
  # Reduce the dimension based on 1st character else return *
  if str(row) == "nan":
    return np.nan
  
  if prefix_count > len(row):
    return "#"
  
  if row[0:prefix_count].isalpha():
    return row[0:prefix_count].lower()
  else:
    return "*"

# %%
def feature_engineering(df):
  # Create a column to indicate funder with atleast 5 pumps maintained.
  value_count_funder = df.funder.value_counts()
  df['funder_aleast_5'] = df['funder'].apply(atleast, 
                                            args=(value_count_funder,))
  
  # Create a column to indicate installer with atleast 5 pumps maintained.
  value_count_installer = df.installer.value_counts()
  df['installer_aleast_5'] = df['installer'].apply(atleast, 
                                            args=(value_count_installer,))
  
  # Apply mean for missing values of latitude and longitude
  mean_longitude = df['longitude'].mean()
  df['longitude'] = df['longitude'].apply(lambda x: mean_longitude \
                                          if round(x, 2) == 0 else x)
  mean_latitude = df['latitude'].mean()
  df['latitude'] = df['latitude'].apply(lambda x: mean_latitude \
                                        if round(x, 2) == 0 else x)
  
  # Grouping wpt_name, subvillage based on 1st alphabet
  df['wpt_name_character_grouping'] = df['wpt_name'].apply(character_grouping)
  df['subvillage_character_grouping'] = \
    df['subvillage'].apply(character_grouping)
  
  # Classify lga based on Rural, Urban and others
  df['lga_classify'] = df['lga'].apply(classify_lga)
  
  # Grouping ward, scheme_name based on 1st alphabet
  df['ward_character_grouping'] = df['ward'].apply(character_grouping)
  df['scheme_name_character_grouping'] = \
    df['scheme_name'].apply(character_grouping)
  
  # Grouping based on prefix
  df['funder_prefix_grouping'] = df['funder'].apply(prefix_grouping)
  df['installer_prefix_grouping'] = df['installer'].apply(prefix_grouping)
  df['wpt_name_prefix_grouping'] = df['wpt_name'].apply(prefix_grouping)
  df['subvillage_prefix_grouping'] = df['subvillage'].apply(prefix_grouping)
  df['lga_prefix_grouping'] = df['lga'].apply(prefix_grouping)
  df['ward_prefix_grouping'] = df['ward'].apply(prefix_grouping)
  df['scheme_name_prefix_grouping'] = df['scheme_name'].apply(prefix_grouping)

feature_engineering(train_features_df)

# %%
# Selecting independent and dependent variables.

X = train_features_df.drop(columns=['id', 'funder', 'installer', 'wpt_name', 
                                    'subvillage', 'lga','ward','scheme_name'])
y = train_labels_df.status_group

# %%
# Split data into train and test using k-fold cross-validation
# with independent test data set.
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.25,
                                                    shuffle=True,
                                                    random_state=42
                                                   )

# %%
# Get quick initial metrics estimate.

# Using sklearn accuracy_score
import numpy as np
from sklearn.metrics import accuracy_score

majority_class = y_train.mode()[0]
prediction = np.full(shape=y_train.shape, 
                     fill_value=majority_class)

print(f'accuracy score {accuracy_score(y_train, prediction)}')


# Using simple pandas value counts method
print(y_train.value_counts(normalize=True))
# Out:
# accuracy score 0.542334455667789
# functional                 0.542334
# non functional             0.384871
# functional needs repair    0.072795
# Name: status_group, dtype: float64

# %%
# Data pre-processing, Feature selection and Model selection.

# Imports for pipeline
from sklearn.pipeline import make_pipeline

import category_encoders as ce
from sklearn.preprocessing import RobustScaler
from xgboost import XGBClassifier

# %%
# Create pipeline
pipeline = make_pipeline(\
                         ce.BinaryEncoder(),
                         RobustScaler(),
                         XGBClassifier())

# %%
# Model validation.
from sklearn.model_selection import GridSearchCV 

param_grid = {
    'xgbclassifier__max_depth': [3, 4, 5, 6],
    'xgbclassifier__learning_rate': [0.1, 0.2, 0.3, 0.5]
}

"""param_grid = {
    'xgbclassifier__max_depth': [5],
    'xgbclassifier__learning_rate': [0.2]
}"""

gridsearch = GridSearchCV(pipeline, param_grid=param_grid, cv=3,
                         scoring='accuracy', verbose=20)

gridsearch.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 16 candidates, totalling 48 fits
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=3 ....
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=3, score=0.7400848427715305, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=3 ....
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.3min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=3, score=0.7456565656565657, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=3 ....
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:  2.6min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=3, score=0.7410600040406762, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=4 ....
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:  3.9min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=4, score=0.7565147128139519, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=4 ....
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:  5.4min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=4, score=0.7597306397306397, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=4 ....
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  6.9min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=4, score=0.7583002222371877, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=5 ....
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:  8.4min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=5, score=0.7699144838731399, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=5 ....
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed: 10.2min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=5, score=0.7703703703703704, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=5 ....
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed: 11.9min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=5, score=0.7700181830426291, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=6 ....
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed: 13.6min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=6, score=0.7815635310753485, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=6 ....
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed: 15.6min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=6, score=0.781077441077441, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=6 ....
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed: 17.5min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.1, xgbclassifier__max_depth=6, score=0.7779648461175837, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=3 ....
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed: 19.5min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=3, score=0.7550333310888155, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=3 ....
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed: 20.8min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=3, score=0.7615488215488215, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=3 ....
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed: 22.1min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=3, score=0.7561451949626238, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=4 ....
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed: 23.4min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=4, score=0.7685004376809642, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=4 ....
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed: 24.9min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=4, score=0.7696969696969697, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=4 ....
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed: 26.4min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=4, score=0.7696141154286484, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=5 ....
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed: 27.9min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=5, score=0.7824388930038382, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=5 ....
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed: 29.7min remaining:    0.0s
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=5, score=0.7833670033670034, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=5 ....
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=5, score=0.78146676543875, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=6 ....
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=6, score=0.7906538280250488, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=6 ....
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=6, score=0.791043771043771, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=6 ....
# [CV]  xgbclassifier__learning_rate=0.2, xgbclassifier__max_depth=6, score=0.7879318472624419, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=3 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=3, score=0.7603528381927143, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=3 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=3, score=0.7659259259259259, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=3 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=3, score=0.7652367162771904, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=4 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=4, score=0.7773887280317824, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=4 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=4, score=0.7772390572390573, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=4 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=4, score=0.7756077850360293, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=5 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=5, score=0.7851323143222678, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=5 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=5, score=0.7877441077441077, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=5 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=5, score=0.7856421307832178, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=6 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=6, score=0.7950306376674972, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=6 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=6, score=0.7925925925925926, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=6 ....
# [CV]  xgbclassifier__learning_rate=0.3, xgbclassifier__max_depth=6, score=0.7941948952791433, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=3 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=3, score=0.7689044508787287, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=3 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=3, score=0.7731313131313131, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=3 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=3, score=0.7693447370193279, total= 1.3min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=4 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=4, score=0.7842569523937782, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=4 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=4, score=0.7811447811447811, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=4 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=4, score=0.7821402114620514, total= 1.5min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=5 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=5, score=0.7904518214261665, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=5 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=5, score=0.7923905723905724, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=5 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=5, score=0.7891440501043842, total= 1.7min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=6 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=6, score=0.7948959666015757, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=6 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=6, score=0.7918518518518518, total= 1.9min
# [CV] xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=6 ....
# [CV]  xgbclassifier__learning_rate=0.5, xgbclassifier__max_depth=6, score=0.7955417873257459, total= 1.9min
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 77.8min finished
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=Pipeline(memory=None,
#      steps=[('binaryencoder', BinaryEncoder(cols=None, drop_invariant=False, handle_unknown='impute',
#        impute_missing=True, return_df=True, verbose=0)), ('robustscaler', RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)), ('xgbclassifier', XGBClassi...
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1))]),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'xgbclassifier__max_depth': [3, 4, 5, 6], 'xgbclassifier__learning_rate': [0.1, 0.2, 0.3, 0.5]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=20)

# %%
# Interpret the results.

# Best cross validation score
print('Cross Validation Score:', gridsearch.best_score_)

# Best parameters which resulted in the best score
print('Best Parameters:', gridsearch.best_params_)
# Out:
# Cross Validation Score: 0.7940965207631874
# Best Parameters: {'xgbclassifier__learning_rate': 0.5, 'xgbclassifier__max_depth': 6}

# %% [markdown]
# Cross Validation Score: 0.7533333333333333
# Best Parameters: {'xgbclassifier__learning_rate': 0.2, 'xgbclassifier__max_depth': 5}
#
# Cross Validation Score: 0.7576
# Best Parameters: {'xgbclassifier__learning_rate': 0.2, 'xgbclassifier__max_depth': 5}

# %%
#Get the best model and check it against test data set.

# Predict with X_test features
y_pred = gridsearch.predict(X_test)

# Compare predictions to y_test labels
test_score = accuracy_score(y_test, y_pred)
print('Accuracy Score on test data set:', test_score)
# Out:
# Accuracy Score on test data set: 0.7999326599326599

# %%
test_features_df = pd.read_csv('test_features.csv', na_values=nan_values_list)
feature_engineering(test_features_df)

X_submission = test_features_df.drop(columns =['id', 'funder', 'installer', 'wpt_name', 'subvillage', 
                                    'lga','ward','scheme_name'])

# Predict with X_submission features
y_submission = gridsearch.predict(X_submission)

y_submission_df = pd.DataFrame(y_submission, columns=['status_group'])
output_for_submission = test_features_df.join(y_submission_df).loc[:, ['id','status_group']]

# %%
output_for_submission.head()
# Out:
#       id    status_group
# 0  50785  non functional
# 1  51630      functional
# 2  17168      functional
# 3  45559  non functional
# 4  49871      functional

# %%
print(output_for_submission.status_group.value_counts())
print(output_for_submission.shape)
# Out:
# functional                 8740
# non functional             5107
# functional needs repair     511
# Name: status_group, dtype: int64
# (14358, 2)

# %%
print(output_for_submission.to_csv(index=False))
# Out:
# id,status_group
# 50785,non functional
# 51630,functional
# 17168,functional
# 45559,non functional
# 49871,functional
# 52449,functional
# 24806,functional
# 28965,non functional
# 36301,non functional
# 54122,functional
# 419,functional
# 45750,non functional
# 653,non functional
# 14017,non functional
# 40228,functional
# 27714,functional
# 28785,non functional
# 18532,non functional
# 69961,functional
# 55083,non functional
# 8691,non functional
# 30331,non functional
# 70970,functional
# 61136,functional
# 28799,non functional
# 46825,non functional
# 44718,functional needs repair
# 37350,functional
# 65738,functional
# 3271,non functional
# 42658,functional
# 67523,functional
# 37034,functional
# 42432,functional
# 27420,functional
# 707,functional
# 48489,non functional
# 51008,non functional
# 72562,non functional
# 10275,non functional
# 53540,non functional
# 43291,non functional
# 62343,non functional
# 1649,functional
# 8822,functional
# 10352,non functional
# 50878,functional
# 15266,functional
# 51956,functional
# 44099,non functional
# 59,non functional
# 51359,non functional
# 15962,non functional
# 17853,functional needs repair
# 42040,non functional
# 72243,functional
# 63653,non functional
# 72053,functional
# 29351,functional
# 51897,non functional
# 20376,functional
# 26804,functional
# 67303,functional
# 69780,non functional
# 54665,functional
# 39341,non functional
# 8869,functional needs repair
# 20691,non functional
# 19693,non functional
# 14321,non functional
# 63059,functional
# 67403,functional
# 28912,functional
# 12549,functional
# 24328,non functional
# 13750,non functional
# 1574,non functional
# 44149,non functional
# 53917,functional
# 22705,functional
# 15644,non functional
# 20773,non functional
# 33092,functional
# 54392,functional
# 37850,functional
# 5576,non functional
# 9971,non functional
# 57508,functional
# 25872,functional
# 43978,functional
# 38181,functional
# 24325,non functional
# 2724,non functional
# 34794,non functional
# 56525,non functional
# 63155,non functional
# 67247,functional
# 23387,functional
# 17873,non functional
# 18197,functional
# 24834,functional
# 4091,functional
# 33261,non functional
# 44384,functional
# 62096,non functional
# 64554,functional
# 68314,functional
# 53,non functional
# 23426,functional
# 38259,non functional
# 16631,non functional
# 43162,functional
# 44492,non functional
# 38884,non functional
# 13690,functional
# 60335,functional
# 31856,non functional
# 67891,functional
# 25564,non functional
# 55293,functional
# 31866,functional
# 71178,non functional
# 60279,functional
# 28615,functional
# 8744,functional
# 48308,non functional
# 49626,non functional
# 38098,functional
# 30309,functional needs repair
# 8015,functional
# 3496,functional needs repair
# 56971,functional
# 68616,functional
# 8646,functional
# 74104,functional
# 37501,non functional
# 69202,non functional
# 68409,functional
# 51847,non functional
# 55647,non functional
# 17923,non functional
# 71743,non functional
# 51539,functional
# 73819,functional
# 66881,functional
# 58768,functional
# 2648,functional
# 68933,functional
# 12427,functional
# 16633,non functional
# 24123,functional
# 58551,non functional
# 17132,functional
# 3027,non functional
# 2651,non functional
# 25998,non functional
# 63400,functional
# 50028,non functional
# 67897,functional
# 21425,non functional
# 71756,functional
# 16862,functional
# 15420,non functional
# 712,functional
# 54368,non functional
# 2866,functional
# 51130,functional needs repair
# 27993,non functional
# 21621,non functional
# 66038,functional
# 42182,functional
# 17694,non functional
# 57759,functional
# 47978,functional
# 52359,functional
# 69656,non functional
# 24086,non functional
# 43579,functional
# 43284,non functional
# 2877,non functional
# 21171,functional
# 40982,functional
# 48396,functional
# 13323,functional needs repair
# 28467,functional
# 2768,functional
# 73593,functional
# 65164,functional
# 69976,non functional
# 52145,functional needs repair
# 49259,non functional
# 23542,functional
# 69848,non functional
# 9305,functional
# 14359,non functional
# 28925,non functional
# 21243,functional
# 10616,non functional
# 73667,functional
# 20566,functional
# 63711,functional
# 72840,functional
# 31651,non functional
# 3782,functional needs repair
# 6799,non functional
# 21402,functional
# 35390,functional
# 12636,non functional
# 36887,functional
# 20086,non functional
# 48029,functional
# 29927,non functional
# 2930,functional
# 41800,functional
# 68349,non functional
# 61678,non functional
# 30270,functional
# 4678,functional
# 9392,non functional
# 20735,functional
# 49300,non functional
# 70339,functional
# 25572,functional
# 61445,non functional
# 32190,functional
# 39189,functional
# 14853,functional needs repair
# 52207,functional
# 48035,functional
# 73122,functional
# 16352,functional
# 42721,functional
# 15116,functional
# 7837,non functional
# 56907,functional
# 46382,functional
# 64521,non functional
# 67362,functional
# 61861,functional
# 72139,non functional
# 3398,functional
# 62911,functional
# 48152,functional
# 48001,functional
# 64118,functional
# 65793,functional
# 61557,functional
# 1830,functional
# 50553,functional
# 51961,functional
# 38481,functional
# 48371,functional
# 56540,functional
# 18142,functional
# 72934,non functional
# 39300,non functional
# 40115,non functional
# 3793,functional
# 59318,non functional
# 68070,functional
# 67527,non functional
# 34898,functional
# 26592,functional
# 67682,functional
# 52394,functional
# 32218,functional
# 69045,functional
# 12808,functional
# 64126,functional
# 64903,functional needs repair
# 35165,functional
# 9543,non functional
# 64635,functional
# 47929,functional
# 28329,functional
# 67954,non functional
# 16575,non functional
# 16612,functional
# 73324,non functional
# 7043,functional
# 22174,functional
# 19450,functional
# 35825,functional
# 9854,non functional
# 23254,functional needs repair
# 72170,functional
# 61999,functional
# 70354,non functional
# 6877,non functional
# 47323,non functional
# 48624,non functional
# 6148,non functional
# 59698,non functional
# 67268,functional
# 59174,non functional
# 68916,non functional
# 28358,functional
# 57453,functional
# 71952,non functional
# 1761,functional
# 15234,functional
# 60021,functional
# 22567,functional
# 19872,functional
# 22828,functional
# 34896,functional
# 35570,functional
# 41325,non functional
# 8831,functional
# 5345,functional
# 19379,non functional
# 5514,functional
# 61654,non functional
# 40482,non functional
# 43123,functional
# 40492,non functional
# 68733,non functional
# 3952,non functional
# 70288,non functional
# 30085,functional
# 65837,non functional
# 2465,functional
# 11466,non functional
# 30179,non functional
# 23505,functional
# 48424,functional
# 11150,functional
# 70368,functional
# 26935,non functional
# 5919,functional
# 16652,functional
# 59302,functional
# 24210,non functional
# 6211,functional
# 19743,functional
# 10760,functional
# 48104,functional
# 50171,non functional
# 63137,functional
# 38301,functional
# 10948,functional
# 33232,functional
# 61415,functional
# 69131,functional
# 73555,functional
# 46610,functional
# 20922,functional
# 55743,functional
# 19341,functional
# 9588,non functional
# 3293,functional
# 55490,functional
# 67678,functional
# 36119,non functional
# 62775,non functional
# 68162,functional
# 66128,non functional
# 12036,functional
# 15739,non functional
# 57048,non functional
# 15825,non functional
# 45590,functional
# 18055,functional
# 34073,non functional
# 14860,functional
# 53713,functional
# 69327,non functional
# 60169,functional
# 26798,functional
# 37122,functional
# 22874,non functional
# 58774,functional
# 40092,non functional
# 17487,functional
# 35886,functional
# 49892,functional
# 66338,functional
# 35481,non functional
# 4135,non functional
# 54191,functional
# 31349,functional
# 72271,functional
# 48863,functional
# 13758,non functional
# 33443,functional
# 12003,non functional
# 10845,functional
# 47,functional
# 70492,functional
# 11346,non functional
# 20126,functional
# 51000,functional
# 64505,functional
# 58329,functional
# 6311,non functional
# 22286,functional
# 35013,functional
# 6274,functional
# 30904,non functional
# 46606,non functional
# 18461,functional
# 15256,non functional
# 625,functional
# 42122,functional
# 18277,functional
# 68501,functional
# 8816,functional needs repair
# 62879,functional
# 27712,functional
# 46935,non functional
# 57804,functional
# 57711,functional
# 5516,non functional
# 8305,functional
# 57410,functional
# 51412,non functional
# 25863,functional
# 35994,functional
# 55279,non functional
# 74102,functional
# 38277,functional
# 1998,functional needs repair
# 52056,non functional
# 63679,functional
# 71762,non functional
# 71432,functional
# 45592,functional
# 13663,non functional
# 62227,non functional
# 3730,functional
# 2451,functional
# 46418,non functional
# 45996,non functional
# 60911,non functional
# 46089,functional
# 65579,non functional
# 40407,non functional
# 66663,functional
# 26597,non functional
# 50540,functional
# 58133,non functional
# 1493,functional
# 31503,non functional
# 19466,functional
# 38120,non functional
# 66553,non functional
# 31696,functional
# 33584,non functional
# 48678,functional
# 36112,non functional
# 6294,functional
# 40612,non functional
# 62793,functional
# 2532,non functional
# 38865,non functional
# 35462,non functional
# 51709,functional
# 40624,non functional
# 41745,functional
# 42315,functional
# 38952,non functional
# 45540,functional
# 73833,functional
# 27771,functional
# 9336,functional
# 12545,functional
# 54811,non functional
# 48326,functional
# 31787,non functional
# 61745,non functional
# 42091,functional
# 43727,functional
# 26718,functional
# 3138,functional
# 72932,functional
# 25707,non functional
# 68580,non functional
# 25064,functional
# 7624,non functional
# 3830,non functional
# 13458,functional
# 57377,functional
# 37294,functional
# 39561,functional
# 23237,functional
# 72484,non functional
# 56490,functional
# 13706,non functional
# 43035,non functional
# 14084,non functional
# 55875,functional
# 17299,functional
# 1793,functional
# 70943,functional
# 65720,functional
# 49165,functional
# 18879,functional
# 3574,non functional
# 56735,functional
# 45481,functional
# 51772,non functional
# 74095,functional
# 54000,functional
# 34834,non functional
# 50175,functional
# 35733,functional
# 6808,non functional
# 27311,functional
# 73303,non functional
# 70335,non functional
# 2691,non functional
# 12582,non functional
# 49536,non functional
# 23715,non functional
# 45445,functional
# 52609,functional
# 35087,functional
# 42767,functional
# 24373,functional
# 32895,non functional
# 9328,non functional
# 23275,non functional
# 20054,non functional
# 8378,functional
# 47432,functional
# 49863,functional
# 57828,functional
# 31169,functional
# 38382,functional
# 31205,functional
# 23528,functional
# 26507,non functional
# 67091,non functional
# 47734,functional
# 48521,non functional
# 16963,functional
# 48233,functional
# 58989,functional
# 2399,functional
# 23530,functional
# 46271,non functional
# 71726,functional
# 23526,non functional
# 49861,non functional
# 22619,non functional
# 41264,non functional
# 20623,functional
# 35694,functional
# 68210,non functional
# 13446,functional
# 11321,functional needs repair
# 56312,functional
# 19533,non functional
# 7275,functional
# 48614,functional
# 65873,functional
# 9008,functional
# 36817,functional
# 25767,non functional
# 38460,non functional
# 16756,functional
# 13310,non functional
# 36514,functional
# 57548,functional
# 2809,functional
# 70632,functional
# 17260,functional
# 27950,functional
# 40629,non functional
# 64155,functional
# 50640,non functional
# 67355,functional
# 32132,non functional
# 70868,functional
# 45823,non functional
# 19985,functional
# 61834,non functional
# 54171,non functional
# 62763,functional
# 42408,functional
# 13151,functional
# 28311,functional
# 57775,functional
# 37603,non functional
# 56357,non functional
# 37845,non functional
# 57177,non functional
# 12821,functional
# 8193,non functional
# 49031,functional
# 14011,functional
# 33708,functional
# 68898,non functional
# 37198,non functional
# 11151,functional
# 22264,functional
# 49694,functional
# 47318,non functional
# 46108,functional
# 28297,non functional
# 36340,functional
# 26987,non functional
# 5766,functional
# 25979,non functional
# 73021,functional
# 11908,functional
# 47496,functional
# 61777,functional
# 47591,functional
# 8968,functional
# 45656,functional
# 39630,functional
# 2786,non functional
# 958,functional
# 55843,functional
# 52074,non functional
# 23422,functional
# 55802,functional
# 61634,functional
# 1625,functional
# 37398,non functional
# 51011,functional
# 49595,functional
# 22486,non functional
# 22916,functional
# 45204,non functional
# 74223,functional
# 35533,functional
# 30595,functional
# 47319,non functional
# 32555,non functional
# 9520,functional
# 53253,functional
# 36436,non functional
# 15036,functional
# 23175,functional
# 41998,functional
# 19345,non functional
# 1198,non functional
# 39848,functional
# 39278,functional
# 39844,functional
# 17332,functional
# 51287,non functional
# 49514,non functional
# 64288,functional
# 41782,functional needs repair
# 54572,functional
# 68079,functional
# 68017,non functional
# 66705,functional needs repair
# 5274,functional
# 58230,functional
# 51010,functional
# 46242,functional
# 1917,functional
# 9361,non functional
# 33043,non functional
# 56633,non functional
# 57518,functional
# 51128,non functional
# 4388,functional
# 62267,non functional
# 72473,non functional
# 70957,functional
# 35399,functional
# 33236,functional
# 73183,functional
# 52939,functional
# 66929,non functional
# 54326,functional
# 16343,functional
# 33013,functional
# 60384,non functional
# 41074,non functional
# 71997,functional
# 35190,functional
# 3425,functional
# 4335,functional
# 7399,functional
# 40845,functional
# 27347,non functional
# 10981,functional
# 36447,functional
# 67485,functional
# 11220,functional
# 45857,non functional
# 21806,non functional
# 8771,functional
# 45535,functional
# 8671,functional
# 2252,non functional
# 58078,non functional
# 61068,non functional
# 69204,non functional
# 46930,non functional
# 52104,functional
# 31732,functional
# 21584,functional
# 17045,functional
# 14404,functional
# 39930,non functional
# 38744,functional
# 4339,functional
# 54735,functional
# 51916,functional
# 58114,functional
# 28339,functional needs repair
# 52048,non functional
# 66497,non functional
# 18353,functional
# 16701,non functional
# 59499,non functional
# 66042,non functional
# 43965,functional
# 48361,functional
# 70766,functional
# 9510,non functional
# 28586,non functional
# 28521,non functional
# 18050,functional
# 73151,non functional
# 45011,functional
# 64380,functional
# 66896,functional
# 40184,functional
# 67207,functional
# 70178,functional
# 54063,non functional
# 39252,non functional
# 53773,functional
# 47931,non functional
# 44168,non functional
# 66540,functional
# 54089,non functional
# 29244,functional
# 27525,non functional
# 58991,functional
# 18087,functional
# 67803,functional needs repair
# 48006,functional
# 11788,functional
# 16100,functional
# 16382,functional
# 21208,functional
# 8637,non functional
# 67008,non functional
# 67914,functional
# 7041,non functional
# 43181,non functional
# 26191,non functional
# 14766,functional
# 49812,functional
# 12705,functional
# 25422,non functional
# 9399,non functional
# 4239,functional
# 49442,functional
# 32,functional
# 11443,functional needs repair
# 15492,functional
# 63498,functional
# 12708,non functional
# 19483,functional
# 31204,functional
# 33445,functional
# 40820,functional
# 10279,non functional
# 46718,non functional
# 39000,non functional
# 45897,functional
# 62154,functional
# 50034,functional
# 11853,non functional
# 40426,functional
# 41168,functional
# 58978,functional
# 31363,functional
# 32736,functional
# 29058,functional
# 23824,non functional
# 61885,non functional
# 59187,non functional
# 73243,functional
# 62915,functional
# 1784,functional
# 65951,functional
# 20661,functional
# 55504,functional
# 66975,functional
# 72057,functional
# 49331,functional
# 52682,non functional
# 10460,functional
# 12407,functional
# 69993,functional
# 13012,functional
# 70896,non functional
# 13264,functional
# 51824,non functional
# 60216,functional
# 57481,non functional
# 3996,functional
# 24854,non functional
# 43420,functional
# 70468,non functional
# 38305,non functional
# 57179,functional
# 70388,non functional
# 67589,functional
# 69974,functional
# 8854,functional
# 71663,functional
# 69272,functional
# 49119,non functional
# 15638,functional
# 9086,functional
# 56422,functional
# 39106,functional
# 4515,non functional
# 48594,non functional
# 63779,functional
# 60740,functional
# 61242,functional
# 65001,functional
# 2601,functional
# 52456,functional
# 21873,non functional
# 25505,non functional
# 21890,non functional
# 52336,non functional
# 57756,functional
# 45465,functional needs repair
# 4989,functional
# 51585,functional
# 50533,functional
# 54866,functional
# 50135,non functional
# 26549,functional
# 66920,functional
# 35517,functional
# 390,functional
# 13645,functional
# 39327,non functional
# 58900,functional
# 2100,functional
# 31521,non functional
# 277,functional
# 42545,non functional
# 46861,functional
# 35278,non functional
# 71773,functional
# 52392,non functional
# 47229,functional
# 10716,non functional
# 13923,functional
# 42206,non functional
# 965,functional
# 66646,non functional
# 17301,functional
# 21533,functional needs repair
# 37797,non functional
# 19241,non functional
# 15296,functional
# 41472,functional
# 73859,non functional
# 20153,functional
# 71684,functional
# 8321,functional
# 68979,functional
# 48850,functional
# 64251,functional
# 3583,functional
# 33326,functional
# 8500,functional
# 67047,functional
# 39527,functional
# 3089,non functional
# 66477,non functional
# 24107,functional
# 7823,functional
# 32016,functional
# 35048,non functional
# 70580,non functional
# 47503,functional
# 37357,functional
# 1195,non functional
# 52309,non functional
# 19655,functional
# 39455,functional
# 52757,non functional
# 62729,non functional
# 24324,non functional
# 51298,functional
# 28152,functional
# 14259,non functional
# 47461,functional
# 65878,non functional
# 58913,functional
# 70035,non functional
# 37446,non functional
# 30337,non functional
# 57584,functional
# 67193,functional
# 62103,functional
# 22896,functional
# 5934,non functional
# 61722,functional
# 9299,functional
# 68558,non functional
# 8657,functional
# 54952,functional
# 53160,functional
# 17393,functional
# 33016,functional
# 25929,non functional
# 41102,functional
# 11093,functional
# 52744,functional
# 23484,non functional
# 13139,functional
# 55439,functional
# 41539,functional
# 47692,non functional
# 60165,functional
# 64683,functional
# 7089,functional
# 13516,non functional
# 47720,functional
# 22588,non functional
# 28580,functional
# 9075,non functional
# 25066,non functional
# 28284,functional
# 67568,functional
# 64823,functional
# 8243,non functional
# 2556,functional
# 58746,functional
# 18288,functional
# 72822,functional
# 5178,non functional
# 66294,functional
# 14451,functional
# 48600,functional
# 27513,functional
# 36889,functional
# 663,non functional
# 10646,non functional
# 35103,functional
# 50804,functional
# 29635,functional
# 47604,functional
# 49844,functional
# 69068,functional
# 43074,functional
# 71088,non functional
# 40470,functional
# 21920,non functional
# 51415,functional needs repair
# 15480,non functional
# 21881,functional
# 7780,functional
# 24908,functional
# 53915,functional
# 54560,functional
# 20446,functional
# 5886,non functional
# 52883,non functional
# 30892,functional
# 37432,non functional
# 42574,functional
# 61505,non functional
# 44827,non functional
# 5951,functional
# 48991,functional
# 22821,functional
# 46478,functional
# 19831,functional
# 18472,non functional
# 58686,non functional
# 47419,non functional
# 44921,functional
# 55024,non functional
# 28971,non functional
# 8108,functional
# 32182,functional
# 40513,non functional
# 372,functional
# 49297,functional
# 24407,non functional
# 44874,non functional
# 25119,functional
# 3882,non functional
# 73443,functional
# 56056,non functional
# 22035,non functional
# 46318,functional
# 20802,functional
# 41941,non functional
# 12044,functional
# 47262,functional needs repair
# 19337,functional needs repair
# 38688,non functional
# 45341,non functional
# 55661,functional
# 32322,functional
# 41912,functional
# 26136,non functional
# 13480,functional
# 62035,functional
# 50343,non functional
# 68537,functional
# 52293,functional
# 17764,functional
# 67862,non functional
# 38933,non functional
# 68514,non functional
# 65335,functional
# 31290,non functional
# 72594,functional
# 2854,functional
# 19679,non functional
# 46470,functional
# 9931,non functional
# 39214,functional
# 3982,functional
# 29633,functional
# 50872,functional
# 31969,functional
# 51280,non functional
# 63438,functional
# 52302,non functional
# 44486,functional
# 4641,non functional
# 47724,functional
# 4393,functional
# 54938,non functional
# 66983,non functional
# 55870,non functional
# 62561,non functional
# 7975,non functional
# 9418,non functional
# 4929,functional
# 68311,non functional
# 15225,non functional
# 51854,functional
# 40247,functional
# 37958,functional
# 19319,functional
# 27495,functional
# 20111,functional
# 33231,functional
# 44772,functional
# 53237,functional
# 23279,non functional
# 66738,non functional
# 73053,functional
# 31190,functional
# 54820,functional
# 54173,functional
# 40904,functional
# 43729,functional
# 63132,functional
# 2012,non functional
# 70647,functional
# 6067,functional
# 47835,non functional
# 14510,functional
# 34536,functional needs repair
# 50168,non functional
# 65018,functional
# 4960,functional
# 19291,non functional
# 11480,non functional
# 74179,functional
# 46276,functional
# 69469,functional
# 51844,non functional
# 13340,functional
# 34046,functional needs repair
# 72429,non functional
# 60034,functional
# 36173,functional
# 66575,functional
# 33778,non functional
# 52807,non functional
# 37283,non functional
# 53688,functional
# 54777,non functional
# 10363,non functional
# 42685,functional
# 29334,functional
# 17320,functional
# 7060,non functional
# 3905,non functional
# 59091,functional
# 44927,non functional
# 59415,functional
# 59722,functional
# 49411,functional
# 40903,non functional
# 64786,non functional
# 36207,functional
# 61178,functional
# 55377,functional
# 34300,functional
# 29483,non functional
# 58576,non functional
# 37659,functional
# 63873,functional
# 55723,functional
# 9950,functional
# 49680,functional
# 30329,non functional
# 64912,functional
# 21165,functional
# 42112,functional
# 25108,functional
# 55021,functional
# 14319,functional
# 23587,functional
# 27217,non functional
# 62333,functional
# 3284,functional
# 38299,functional
# 35668,non functional
# 10228,functional
# 67801,non functional
# 63324,functional
# 33451,non functional
# 37149,functional
# 29770,non functional
# 14731,functional
# 7963,functional
# 55945,non functional
# 7645,non functional
# 7244,non functional
# 40114,functional
# 37615,functional
# 54151,non functional
# 64712,functional
# 40499,non functional
# 71171,non functional
# 20712,functional
# 20187,non functional
# 12383,functional
# 33364,functional
# 9646,functional
# 12201,non functional
# 1782,non functional
# 42747,functional
# 12125,functional
# 55023,functional
# 7865,non functional
# 66269,non functional
# 45049,functional
# 4988,functional
# 17387,non functional
# 41771,functional
# 44806,functional needs repair
# 9157,functional
# 70881,functional
# 59951,functional
# 47581,non functional
# 14986,functional
# 71499,non functional
# 32928,non functional
# 11934,functional
# 54065,functional
# 25479,functional
# 38302,non functional
# 32973,non functional
# 52140,functional
# 51060,functional
# 33106,non functional
# 55127,functional
# 8640,functional
# 43117,functional
# 9966,functional
# 11183,non functional
# 72250,non functional
# 50586,functional
# 48093,functional
# 37435,functional
# 9379,non functional
# 65657,non functional
# 34535,functional
# 26262,functional
# 14458,functional
# 33972,functional needs repair
# 40238,non functional
# 70610,functional
# 71481,functional
# 10946,functional
# 68239,functional needs repair
# 56314,non functional
# 20772,non functional
# 41027,non functional
# 57639,functional
# 42841,functional
# 8016,functional
# 38349,non functional
# 68114,non functional
# 53733,non functional
# 53513,functional
# 50420,non functional
# 31043,functional
# 11436,functional
# 66544,functional
# 66297,functional
# 9975,functional
# 21663,functional
# 66747,functional
# 8343,non functional
# 43675,functional
# 12325,functional
# 27609,functional
# 70092,functional
# 4092,non functional
# 60469,functional needs repair
# 15869,functional
# 31689,non functional
# 40197,functional
# 35039,functional
# 19866,functional
# 65864,non functional
# 54111,functional
# 65616,functional
# 55924,non functional
# 48299,functional
# 51679,non functional
# 7861,functional
# 74037,functional
# 2367,functional
# 60329,functional
# 16467,non functional
# 36876,non functional
# 42906,non functional
# 58855,functional
# 48072,non functional
# 34861,functional
# 38446,functional
# 25076,functional
# 42010,functional
# 49961,non functional
# 32989,non functional
# 17483,non functional
# 54815,functional
# 16359,functional
# 54840,non functional
# 6252,functional
# 46589,non functional
# 65044,functional
# 52749,functional
# 31792,non functional
# 72814,functional needs repair
# 19523,functional
# 32936,non functional
# 28011,functional
# 49940,functional
# 21296,non functional
# 57692,non functional
# 60900,functional
# 69726,functional
# 4707,functional
# 5501,non functional
# 37805,non functional
# 20466,non functional
# 915,functional
# 60509,functional
# 22552,functional
# 47386,non functional
# 8521,functional
# 54730,non functional
# 58417,functional
# 11731,non functional
# 40490,non functional
# 17385,functional
# 63184,functional
# 45621,non functional
# 42679,non functional
# 64602,functional needs repair
# 33317,non functional
# 38658,functional
# 64299,non functional
# 36030,non functional
# 18940,functional
# 45669,functional
# 19668,functional
# 44209,functional
# 73269,non functional
# 72767,functional
# 68471,functional
# 907,functional
# 57724,functional
# 19492,functional
# 18247,functional
# 61793,non functional
# 68182,functional
# 69769,functional
# 1580,functional
# 9327,functional
# 18330,non functional
# 9250,functional
# 29932,non functional
# 22830,non functional
# 58200,non functional
# 30920,functional
# 9138,functional
# 50234,functional
# 54691,functional
# 16393,functional
# 56549,non functional
# 9832,functional
# 31881,non functional
# 12886,non functional
# 58897,functional
# 830,functional
# 15950,functional
# 26265,non functional
# 46220,non functional
# 22347,functional
# 2860,functional
# 19021,functional
# 3484,functional needs repair
# 30298,non functional
# 39782,non functional
# 74005,functional
# 5674,functional
# 9381,functional
# 3895,non functional
# 1673,non functional
# 29551,functional
# 41475,non functional
# 67870,functional
# 2791,functional
# 42255,functional
# 67164,non functional
# 12440,functional
# 13193,non functional
# 60880,functional needs repair
# 71008,functional
# 67514,functional
# 383,non functional
# 23977,non functional
# 70543,functional
# 2906,functional
# 33810,functional
# 10021,non functional
# 46730,functional
# 1663,functional
# 2408,functional
# 72505,functional
# 65019,non functional
# 42313,functional
# 340,non functional
# 50285,non functional
# 3409,functional needs repair
# 26378,functional needs repair
# 47552,functional
# 32262,functional
# 58637,functional
# 34827,functional
# 63294,non functional
# 44867,functional
# 26751,non functional
# 66574,functional
# 21479,functional
# 57899,functional
# 60079,non functional
# 62070,functional
# 20628,non functional
# 11344,functional
# 62122,functional
# 51867,functional
# 51667,non functional
# 16857,non functional
# 27022,non functional
# 10438,functional
# 57755,non functional
# 22384,functional
# 3380,functional
# 41843,functional
# 35208,functional needs repair
# 37152,non functional
# 47925,non functional
# 43946,functional
# 2932,functional
# 11829,non functional
# 59013,functional
# 48338,non functional
# 71276,functional
# 62998,non functional
# 6708,non functional
# 9969,functional
# 5567,functional
# 61598,functional
# 20745,functional
# 72485,non functional
# 53890,functional
# 62984,functional
# 56024,functional
# 64958,functional
# 36386,functional
# 12970,functional
# 63672,functional
# 1545,functional
# 68416,non functional
# 53929,non functional
# 59291,functional
# 20931,functional
# 18781,functional
# 15430,non functional
# 54042,functional
# 56896,non functional
# 2579,functional
# 65982,non functional
# 8486,functional
# 15871,non functional
# 36433,functional
# 65239,non functional
# 42513,functional
# 63248,functional
# 2959,functional
# 64833,functional
# 54346,functional
# 12284,functional
# 18056,functional
# 9415,non functional
# 67761,non functional
# 60358,functional
# 72803,functional
# 71644,non functional
# 43929,non functional
# 23370,functional
# 38121,non functional
# 71352,functional
# 26630,functional
# 72503,functional
# 36667,non functional
# 13838,non functional
# 73762,functional
# 56917,non functional
# 64901,functional
# 11878,non functional
# 11761,functional
# 22410,functional
# 29102,functional
# 36539,non functional
# 9758,non functional
# 28981,non functional
# 56273,functional
# 35854,non functional
# 38840,non functional
# 32235,functional
# 36097,non functional
# 54661,non functional
# 61700,non functional
# 71556,functional
# 9296,non functional
# 26823,functional
# 45401,functional
# 862,functional
# 12857,non functional
# 60984,functional
# 68476,functional
# 18299,functional needs repair
# 48846,functional
# 6446,non functional
# 63522,functional
# 66298,functional
# 39348,functional
# 25325,non functional
# 38166,functional
# 10753,functional
# 6496,non functional
# 66416,functional needs repair
# 47968,functional
# 30436,non functional
# 53608,functional
# 66036,non functional
# 46595,non functional
# 18890,non functional
# 1978,functional
# 10656,functional
# 69297,non functional
# 43482,non functional
# 43158,functional
# 18733,functional
# 27893,functional
# 72342,functional
# 37520,functional
# 11453,functional
# 39911,non functional
# 51620,functional
# 18133,functional
# 4572,functional
# 55691,functional
# 42966,functional
# 66569,non functional
# 7200,non functional
# 53136,functional
# 25723,non functional
# 66123,functional
# 7672,functional
# 37943,functional
# 2142,functional
# 66405,functional
# 13101,functional
# 73963,non functional
# 26444,non functional
# 19007,functional
# 71761,functional
# 1467,non functional
# 35518,non functional
# 32922,functional
# 43852,functional
# 29438,functional
# 56706,functional
# 39407,functional
# 58835,functional
# 9994,functional
# 7622,non functional
# 34194,functional
# 13045,functional
# 32959,functional
# 50876,functional
# 31094,functional
# 37473,functional
# 61430,functional
# 47922,functional
# 52355,functional
# 65517,non functional
# 42861,non functional
# 59615,non functional
# 28406,functional
# 3716,functional
# 219,functional
# 2079,non functional
# 3612,functional
# 50670,functional
# 33118,non functional
# 56582,functional
# 7760,functional
# 39295,functional
# 68787,functional
# 64264,non functional
# 35160,functional
# 49452,functional
# 53668,functional
# 67380,functional
# 45974,functional
# 11062,non functional
# 27946,non functional
# 50414,functional
# 38773,non functional
# 39624,functional
# 72477,non functional
# 61146,functional
# 22496,functional
# 39554,non functional
# 23463,non functional
# 26384,non functional
# 42071,functional
# 38972,functional
# 44617,non functional
# 32282,functional
# 8586,functional
# 36903,functional
# 55556,functional needs repair
# 21436,functional
# 17030,functional
# 51806,non functional
# 44903,non functional
# 1957,non functional
# 20102,functional
# 39391,functional
# 10871,functional
# 67815,functional
# 19183,non functional
# 59743,functional
# 11844,functional
# 40062,non functional
# 40682,functional
# 71690,functional
# 22833,functional
# 16908,non functional
# 43496,non functional
# 62050,non functional
# 65634,functional
# 6309,non functional
# 38784,functional
# 38329,functional
# 69029,non functional
# 25515,non functional
# 30870,non functional
# 34228,functional
# 42698,functional
# 31674,functional
# 2848,functional needs repair
# 52616,functional
# 1188,functional
# 13957,functional
# 20847,functional
# 44133,non functional
# 47704,functional
# 68173,functional
# 40526,functional
# 26285,non functional
# 67502,non functional
# 57809,functional
# 3915,non functional
# 69110,functional needs repair
# 21675,functional
# 16738,functional
# 13627,functional
# 13404,non functional
# 16649,functional
# 8572,functional
# 71169,functional
# 71519,functional
# 72287,non functional
# 19168,functional
# 25981,functional
# 33996,non functional
# 69749,functional
# 53037,non functional
# 49611,functional
# 52353,non functional
# 71599,functional
# 29631,functional
# 54016,functional
# 71623,non functional
# 67739,functional
# 30275,functional needs repair
# 29073,functional
# 59974,functional
# 47612,functional
# 12002,non functional
# 10489,non functional
# 49293,functional needs repair
# 23467,functional
# 6668,functional
# 6876,non functional
# 11289,non functional
# 30283,functional
# 55091,non functional
# 26166,functional
# 3449,functional
# 7498,functional
# 62730,functional
# 68654,non functional
# 5300,functional
# 22742,functional
# 2653,non functional
# 71210,functional
# 24301,non functional
# 51174,functional
# 57324,functional
# 47760,functional needs repair
# 34478,functional
# 44012,functional
# 50314,non functional
# 24528,functional
# 57041,functional
# 6407,non functional
# 42635,non functional
# 67087,functional
# 7398,non functional
# 20430,non functional
# 60819,functional
# 59586,functional
# 49192,functional
# 39902,functional
# 52301,non functional
# 50482,functional
# 36023,non functional
# 42509,non functional
# 42398,functional
# 56132,functional
# 37018,functional
# 33205,functional
# 57405,non functional
# 66229,functional
# 22953,non functional
# 67348,functional
# 10496,functional
# 49208,non functional
# 51648,functional
# 49307,non functional
# 53899,functional
# 46623,functional
# 12537,functional
# 1365,non functional
# 54115,functional
# 52656,functional
# 40498,non functional
# 48970,non functional
# 56235,functional
# 36070,functional
# 63964,functional
# 32271,functional
# 15011,functional
# 38607,functional
# 39836,non functional
# 65630,non functional
# 58295,functional
# 4210,functional
# 3161,functional
# 21846,functional
# 28509,functional
# 20933,functional
# 20195,non functional
# 528,functional
# 55726,functional needs repair
# 39291,non functional
# 39436,functional
# 29216,functional
# 12682,non functional
# 48580,functional needs repair
# 22504,functional
# 54078,functional
# 18687,functional needs repair
# 41128,non functional
# 73213,non functional
# 52967,functional
# 73043,functional
# 23440,functional
# 51098,non functional
# 37286,functional
# 3953,functional
# 70347,functional
# 61706,functional
# 45392,non functional
# 12844,functional
# 8890,functional
# 49091,functional
# 44085,functional
# 44799,non functional
# 36158,functional
# 36397,functional
# 13057,functional
# 5874,functional
# 9067,non functional
# 15956,functional
# 3693,non functional
# 65220,functional needs repair
# 31365,functional
# 60072,functional
# 45524,non functional
# 536,non functional
# 21099,non functional
# 45506,functional
# 39120,functional
# 66657,non functional
# 20094,functional
# 20309,functional
# 49113,non functional
# 44016,functional
# 7210,functional
# 34555,functional
# 16088,non functional
# 25292,functional
# 60748,non functional
# 27452,functional
# 59367,non functional
# 59662,functional
# 63833,functional
# 63706,functional
# 40887,non functional
# 3501,functional
# 20532,functional needs repair
# 1386,functional needs repair
# 34149,non functional
# 43398,functional
# 49223,non functional
# 58176,non functional
# 57623,non functional
# 12860,functional
# 30913,functional
# 45960,non functional
# 34432,non functional
# 17486,functional
# 37837,functional
# 73292,non functional
# 11651,functional
# 29408,non functional
# 69690,functional
# 53995,functional
# 53366,functional
# 39328,non functional
# 2320,functional
# 67731,functional
# 57014,non functional
# 62940,functional
# 50725,non functional
# 2855,functional
# 25922,functional needs repair
# 19440,functional
# 31206,non functional
# 2349,non functional
# 57290,functional
# 9508,functional
# 66849,non functional
# 62431,functional
# 23245,non functional
# 21360,non functional
# 44870,non functional
# 64287,functional
# 44968,functional
# 61846,functional
# 49580,functional
# 15928,non functional
# 25900,functional
# 31819,non functional
# 48103,functional
# 49852,functional
# 17098,non functional
# 1767,non functional
# 33791,functional
# 60357,non functional
# 27287,non functional
# 50174,functional
# 60161,functional
# 10484,non functional
# 33521,non functional
# 56320,functional
# 33643,non functional
# 22899,functional
# 63343,non functional
# 41463,functional
# 23539,functional
# 2230,functional
# 26037,functional
# 375,non functional
# 39654,functional
# 53096,functional
# 60168,functional
# 16990,functional
# 21007,functional
# 14315,functional
# 2177,functional
# 49269,non functional
# 4671,functional
# 44176,functional
# 40998,non functional
# 7333,non functional
# 64091,functional
# 68831,non functional
# 42058,functional
# 7902,functional
# 65022,functional
# 28086,functional
# 45360,functional
# 45083,functional
# 32905,functional
# 39259,functional
# 38013,functional
# 38895,functional
# 35123,non functional
# 7111,non functional
# 35613,non functional
# 49983,non functional
# 7539,functional
# 70967,functional
# 37779,non functional
# 17732,non functional
# 40619,non functional
# 13128,functional
# 62321,functional
# 41884,functional
# 22763,functional
# 56616,functional
# 59810,functional
# 15364,functional
# 28596,functional
# 16194,functional
# 63304,functional
# 18910,non functional
# 60481,functional needs repair
# 42567,functional
# 44374,non functional
# 1807,functional
# 51223,functional
# 15702,non functional
# 11806,functional
# 54631,functional
# 27402,functional
# 3372,non functional
# 64730,functional
# 17064,functional needs repair
# 26829,functional
# 9453,functional
# 67241,functional
# 73217,functional
# 66403,non functional
# 48472,functional
# 64553,functional
# 24516,non functional
# 20160,functional
# 6966,functional needs repair
# 65057,functional
# 17269,non functional
# 11662,functional
# 27280,functional
# 33060,non functional
# 50189,functional
# 8863,functional
# 18527,functional
# 49700,functional
# 71248,functional
# 52907,non functional
# 7891,non functional
# 50648,non functional
# 51640,functional
# 56160,non functional
# 61205,functional
# 37237,functional
# 39476,functional
# 12645,functional needs repair
# 65423,functional
# 59104,non functional
# 12613,non functional
# 20577,functional
# 32896,functional
# 22800,functional
# 15436,functional
# 28147,non functional
# 62337,functional
# 46824,non functional
# 37508,functional
# 55768,functional
# 60117,functional
# 59651,non functional
# 40212,functional
# 73448,non functional
# 51073,functional
# 5001,functional
# 33581,functional
# 71443,functional
# 52469,non functional
# 56512,non functional
# 36028,functional
# 22096,functional
# 48869,functional
# 2988,functional
# 18857,functional
# 5138,non functional
# 13512,non functional
# 20209,functional
# 48604,non functional
# 66879,functional
# 40331,non functional
# 49860,functional
# 43322,non functional
# 13054,functional
# 51553,functional
# 10459,non functional
# 58533,functional
# 63877,functional
# 42620,functional
# 45603,functional
# 5494,non functional
# 22161,functional
# 3807,non functional
# 9865,functional
# 23557,functional
# 13087,functional
# 67705,functional
# 31275,functional
# 66376,functional
# 29811,functional
# 47938,non functional
# 60613,functional
# 13300,non functional
# 42764,functional
# 62481,functional
# 5483,functional needs repair
# 72602,functional
# 72209,non functional
# 60017,functional
# 320,functional
# 44190,functional
# 44812,functional
# 19675,non functional
# 24619,functional
# 51059,functional
# 4253,functional
# 64624,functional
# 3451,functional
# 28982,functional
# 11328,functional
# 41177,functional
# 15005,functional needs repair
# 42649,non functional
# 33997,non functional
# 9917,functional needs repair
# 55120,functional
# 59177,functional
# 17066,non functional
# 8462,functional
# 28474,functional needs repair
# 19611,non functional
# 53689,functional
# 69613,functional
# 40335,functional
# 21223,functional
# 48646,functional
# 58015,functional
# 56587,functional
# 47054,non functional
# 66850,functional
# 19266,functional
# 41509,functional
# 50766,non functional
# 14113,non functional
# 42577,functional
# 60521,functional
# 31241,functional
# 31095,functional
# 42850,functional needs repair
# 37852,functional
# 62257,functional
# 9974,functional
# 55266,functional
# 58758,non functional
# 28508,functional
# 4268,functional
# 29508,functional
# 51429,functional
# 58930,non functional
# 21969,non functional
# 37997,functional
# 71748,non functional
# 3149,functional
# 74152,functional
# 60368,functional
# 16858,functional
# 37670,non functional
# 35354,functional
# 7892,functional needs repair
# 47875,functional
# 6277,functional
# 1223,non functional
# 17318,non functional
# 9651,functional
# 889,functional
# 32108,functional
# 17178,functional
# 72309,functional
# 7495,functional
# 61011,non functional
# 31353,non functional
# 12647,functional
# 50067,non functional
# 54404,functional
# 45856,functional
# 56731,functional
# 11704,non functional
# 38790,functional
# 36015,non functional
# 40229,functional
# 43850,non functional
# 36182,non functional
# 37563,functional
# 39146,functional
# 28766,functional
# 67633,functional
# 24922,functional
# 51987,non functional
# 52414,functional
# 21708,non functional
# 48070,functional
# 69586,functional
# 16882,non functional
# 23894,non functional
# 18759,non functional
# 62851,functional
# 50087,non functional
# 42665,non functional
# 11705,functional
# 24892,non functional
# 26397,functional
# 15550,non functional
# 37931,functional
# 52844,functional
# 8024,non functional
# 40987,non functional
# 48760,non functional
# 23575,non functional
# 10117,functional
# 10647,non functional
# 42722,non functional
# 45067,non functional
# 60680,non functional
# 54669,non functional
# 7919,functional needs repair
# 58595,functional
# 2381,non functional
# 39457,functional
# 6055,functional
# 59141,functional
# 13698,functional
# 63930,non functional
# 11930,functional
# 57875,functional
# 66958,functional
# 47427,functional
# 42025,non functional
# 10295,functional
# 1468,functional
# 64449,functional
# 35590,functional
# 66187,non functional
# 67742,functional
# 16104,non functional
# 73801,non functional
# 63163,functional
# 60345,functional
# 39099,non functional
# 405,functional
# 58984,functional
# 22877,non functional
# 13783,functional
# 15148,functional
# 67707,non functional
# 570,functional
# 21674,functional
# 49827,functional
# 65611,non functional
# 48052,functional
# 59547,non functional
# 39793,non functional
# 27686,functional
# 53927,functional
# 54485,functional
# 11922,functional
# 34851,non functional
# 14646,functional
# 38991,non functional
# 20155,functional
# 50328,functional needs repair
# 72786,non functional
# 61652,functional
# 10296,functional
# 9126,non functional
# 47495,functional
# 46307,non functional
# 69138,non functional
# 74198,non functional
# 2225,non functional
# 29754,functional
# 59626,functional
# 38715,non functional
# 33644,functional
# 42537,functional
# 6102,functional
# 22099,functional
# 73285,functional
# 30675,functional
# 45645,non functional
# 10133,functional
# 31392,functional
# 53757,functional
# 69091,non functional
# 34819,functional
# 30233,functional
# 8541,functional
# 20185,functional needs repair
# 15100,functional
# 22154,functional needs repair
# 65590,non functional
# 21544,functional
# 33226,functional
# 37935,functional
# 12087,non functional
# 15163,functional
# 37300,functional
# 45039,functional
# 46519,functional
# 8850,non functional
# 7211,functional
# 72111,non functional
# 20652,functional
# 37761,non functional
# 13869,non functional
# 20960,non functional
# 51314,non functional
# 25560,functional
# 48880,non functional
# 17433,functional
# 71960,non functional
# 70739,non functional
# 22260,functional
# 48713,non functional
# 30294,functional
# 27185,functional
# 21593,functional
# 32119,non functional
# 20299,functional needs repair
# 55818,functional
# 74137,non functional
# 46159,functional
# 59203,non functional
# 20171,functional
# 18385,functional
# 44915,non functional
# 15941,functional
# 15865,functional
# 57598,functional
# 56036,functional needs repair
# 35251,non functional
# 31002,functional
# 3720,functional
# 63990,functional
# 7340,functional
# 68382,non functional
# 48833,non functional
# 54309,functional
# 29274,functional
# 26159,functional
# 5756,non functional
# 65520,non functional
# 17723,functional needs repair
# 43704,functional needs repair
# 32284,functional
# 26312,functional
# 54828,non functional
# 21386,functional
# 26077,functional
# 54702,non functional
# 68427,functional
# 41359,non functional
# 57912,functional
# 57126,non functional
# 21321,non functional
# 53202,functional
# 3351,functional
# 41354,functional
# 19050,functional
# 15929,functional
# 31560,non functional
# 61696,functional
# 56022,non functional
# 48422,non functional
# 18651,functional needs repair
# 23414,functional
# 23653,functional
# 4003,functional
# 26311,functional
# 70408,non functional
# 42630,functional
# 64456,functional
# 66412,functional
# 39856,functional
# 54522,functional
# 10505,functional
# 31406,functional
# 28354,functional
# 2621,functional
# 55216,functional
# 40173,non functional
# 37985,functional
# 12109,non functional
# 26963,non functional
# 46197,non functional
# 22081,functional
# 46780,non functional
# 2633,non functional
# 56927,functional
# 59682,functional
# 38169,non functional
# 49662,functional
# 27236,non functional
# 66648,functional
# 60179,functional
# 46608,functional
# 7912,non functional
# 40483,functional
# 28335,non functional
# 64791,functional
# 54743,functional
# 70993,functional
# 46287,functional
# 27169,non functional
# 29471,non functional
# 71476,functional
# 45420,functional
# 71980,non functional
# 72862,functional
# 6168,functional
# 73489,non functional
# 67595,functional
# 37418,functional
# 379,functional
# 61286,functional
# 15933,non functional
# 55858,functional
# 60144,non functional
# 4352,non functional
# 9905,functional
# 27743,functional needs repair
# 35256,functional
# 35537,non functional
# 25120,functional
# 43468,functional
# 53035,functional
# 69597,non functional
# 50701,functional
# 26306,non functional
# 5101,functional
# 50562,functional
# 21381,functional
# 61186,functional needs repair
# 10726,non functional
# 38114,functional needs repair
# 52810,non functional
# 20389,non functional
# 43615,functional needs repair
# 57068,functional
# 49109,functional
# 11086,non functional
# 73675,functional
# 12727,functional
# 48628,functional
# 34433,non functional
# 57340,functional needs repair
# 46701,functional
# 41210,functional
# 49874,functional
# 13390,non functional
# 66488,functional
# 67786,functional
# 66031,non functional
# 32846,functional
# 55470,functional
# 45443,functional
# 33423,functional
# 15595,non functional
# 1466,functional
# 15863,functional needs repair
# 32073,non functional
# 40460,functional
# 58265,functional
# 1177,functional
# 3506,functional
# 64670,functional
# 33300,functional
# 23616,functional
# 27071,functional
# 21045,non functional
# 1122,non functional
# 71564,functional
# 27385,non functional
# 31201,functional
# 28198,functional
# 14685,functional
# 45865,functional
# 55933,functional
# 52283,functional
# 70751,functional
# 22425,functional
# 51604,functional
# 58005,non functional
# 4919,functional needs repair
# 17156,functional
# 59567,functional
# 65060,functional
# 49236,non functional
# 19877,functional
# 32849,non functional
# 3570,functional needs repair
# 38928,functional
# 59251,functional
# 48824,non functional
# 32112,non functional
# 16199,functional
# 56100,non functional
# 72702,functional
# 23112,non functional
# 45281,functional
# 43409,functional
# 68865,functional
# 4312,functional
# 61091,non functional
# 56976,non functional
# 46362,non functional
# 57734,functional needs repair
# 41379,functional
# 60327,functional
# 1519,functional
# 29287,non functional
# 34402,functional
# 9148,functional
# 64266,functional
# 73606,functional
# 68249,functional needs repair
# 44003,functional
# 18466,non functional
# 68420,functional
# 46243,non functional
# 11188,functional
# 28564,functional
# 40356,functional
# 19939,functional
# 18775,functional needs repair
# 73722,functional
# 33239,functional
# 5936,functional
# 3148,non functional
# 45326,functional
# 36943,functional
# 1238,functional
# 45455,non functional
# 5046,functional
# 50201,functional
# 51907,functional
# 20948,functional
# 48682,functional
# 59315,functional
# 1435,functional
# 14086,functional
# 29558,functional
# 22089,non functional
# 73400,functional
# 66429,functional
# 2755,functional
# 63796,functional
# 67737,functional
# 59762,non functional
# 25908,functional
# 35764,functional
# 70922,non functional
# 11159,non functional
# 11628,functional
# 31960,functional
# 3847,functional
# 4196,functional
# 8702,functional
# 62753,functional
# 25848,functional
# 28872,functional
# 43337,functional
# 67715,functional
# 28757,functional
# 25448,functional
# 23451,non functional
# 45735,non functional
# 3976,non functional
# 3137,non functional
# 61760,functional
# 63917,non functional
# 32584,functional
# 24156,non functional
# 18854,non functional
# 14490,functional
# 58616,non functional
# 26218,functional
# 31306,non functional
# 44316,functional
# 15527,functional
# 65289,functional
# 72855,functional
# 58418,functional
# 38097,non functional
# 28115,functional
# 70693,non functional
# 34833,non functional
# 72223,non functional
# 14932,non functional
# 365,functional
# 409,functional
# 19309,functional
# 37604,non functional
# 24608,non functional
# 52728,functional
# 14846,functional
# 10844,functional
# 51340,functional
# 13814,non functional
# 41995,functional
# 67578,non functional
# 2135,functional
# 49843,functional
# 31987,non functional
# 6987,functional
# 54099,functional
# 7852,non functional
# 68627,functional
# 45474,functional
# 66915,functional
# 61047,functional
# 54566,functional
# 23049,functional
# 70266,functional
# 6688,functional
# 33425,functional
# 42917,non functional
# 11032,functional
# 69274,non functional
# 32687,functional
# 58370,functional
# 8821,functional
# 30476,functional
# 48063,functional
# 71219,functional
# 51924,non functional
# 54852,functional needs repair
# 55782,non functional
# 42818,functional
# 19449,functional
# 64942,non functional
# 48996,functional
# 71646,functional
# 13612,non functional
# 27573,functional
# 12482,functional
# 43614,non functional
# 73216,functional
# 43856,functional
# 52504,functional
# 57351,functional
# 32175,functional
# 29021,non functional
# 2196,non functional
# 54583,non functional
# 42867,functional
# 8195,functional
# 5379,non functional
# 65155,non functional
# 30669,functional
# 55877,functional needs repair
# 31639,non functional
# 60039,non functional
# 66907,functional needs repair
# 41917,non functional
# 63463,functional
# 22131,functional
# 40052,functional
# 5166,non functional
# 1792,non functional
# 18292,non functional
# 29441,functional
# 16170,functional
# 69109,non functional
# 46345,non functional
# 53730,functional
# 3378,functional
# 38297,functional
# 1988,functional
# 19338,non functional
# 71256,functional
# 33455,functional
# 24928,functional
# 14448,functional
# 63962,functional
# 2808,functional
# 36265,functional
# 57164,functional
# 54766,functional
# 10445,non functional
# 69659,non functional
# 53011,non functional
# 67787,functional
# 39504,functional needs repair
# ...
# 59667,functional
# 2249,non functional
# 19840,functional
# 32715,non functional
# 39154,functional
# 43541,functional
# 3497,functional
# 51049,non functional
# 4005,functional
# 30463,functional
# 22064,non functional
# 42930,functional
# 51981,functional
# 13120,functional
# 15575,functional
# 37358,functional
# 18770,functional
# 54680,functional
# 15607,non functional
# 29377,functional
# 28331,functional
# 13122,functional
# 61918,functional
# 35482,functional
# 22663,functional
# 49587,functional
# 3773,functional
# 42811,non functional
# 68178,non functional
# 47893,functional
# 70000,functional
# 27493,non functional
# 45643,non functional
# 3839,non functional
# 39750,functional
# 7781,non functional
# 24977,functional
# 50497,non functional
# 73994,functional needs repair
# 24296,functional
# 23814,functional
# 23516,non functional
# 13565,functional needs repair
# 58206,non functional
# 64835,functional
# 24276,functional
# 57505,functional
# 74148,functional
# 14845,functional
# 2063,non functional
# 57275,non functional
# 31377,functional
# 68341,functional
# 59106,functional
# 4037,non functional
# 32233,non functional
# 5068,non functional
# 19704,functional
# 4794,non functional
# 20541,non functional
# 45174,non functional
# 62718,functional
# 24658,functional
# 12018,non functional
# 67575,non functional
# 51143,functional
# 45461,functional
# 21405,non functional
# 36186,non functional
# 9890,functional
# 7595,functional
# 10899,non functional
# 2446,functional
# 27297,functional
# 26753,functional
# 29672,functional
# 49458,non functional
# 5596,functional
# 12747,functional
# 17935,functional
# 34361,functional
# 19181,functional
# 56153,functional
# 20599,non functional
# 29967,functional
# 68398,non functional
# 18245,non functional
# 57407,functional
# 8234,functional
# 44775,functional
# 69030,functional
# 39122,non functional
# 46966,non functional
# 40949,non functional
# 47528,functional
# 16717,functional
# 4499,functional
# 53922,non functional
# 324,non functional
# 54597,non functional
# 51029,non functional
# 59845,functional
# 19328,functional
# 44516,non functional
# 72333,non functional
# 32788,functional
# 2655,functional needs repair
# 25850,non functional
# 49814,functional
# 25897,functional
# 26769,functional
# 68324,functional needs repair
# 21148,functional
# 71091,non functional
# 61966,non functional
# 17994,non functional
# 40411,non functional
# 5470,non functional
# 58524,non functional
# 63166,functional
# 23946,functional
# 64024,functional
# 2003,non functional
# 2053,functional
# 24762,functional
# 9002,non functional
# 71094,functional
# 69653,functional
# 36703,functional
# 46114,functional
# 5887,non functional
# 7380,functional
# 38522,functional
# 28841,functional needs repair
# 39777,functional
# 71093,functional
# 26440,non functional
# 49676,non functional
# 15942,non functional
# 12583,functional
# 51254,functional
# 72092,functional
# 42333,functional
# 39340,non functional
# 27026,functional
# 16713,functional
# 36167,functional needs repair
# 28528,functional
# 62788,non functional
# 30412,non functional
# 34088,functional
# 9938,functional
# 28683,non functional
# 70837,functional
# 59221,non functional
# 9356,non functional
# 61747,functional
# 23679,functional
# 13,non functional
# 38836,functional
# 60482,functional
# 26273,functional
# 34791,functional
# 18549,functional
# 46422,functional
# 40033,functional
# 9212,non functional
# 65977,functional
# 57512,functional
# 4954,functional
# 4124,functional
# 49162,functional
# 29784,non functional
# 2370,non functional
# 18853,functional
# 63999,non functional
# 34865,functional
# 61892,functional
# 3336,non functional
# 37538,non functional
# 51955,non functional
# 60757,non functional
# 18774,functional
# 57855,functional
# 42919,functional
# 54874,non functional
# 42338,non functional
# 60898,functional
# 59275,functional
# 27598,functional
# 54119,non functional
# 10335,non functional
# 69180,non functional
# 66078,functional
# 35942,non functional
# 61807,functional needs repair
# 26827,functional
# 26949,non functional
# 52753,non functional
# 40967,functional
# 13907,functional
# 42922,functional needs repair
# 11730,functional
# 68874,functional
# 18798,functional
# 10850,non functional
# 20450,functional
# 28042,functional
# 49972,non functional
# 60893,functional
# 11772,functional
# 2002,functional
# 22122,non functional
# 11911,functional
# 16789,functional
# 53602,functional
# 49350,functional
# 52936,non functional
# 14161,functional
# 58271,functional
# 38057,non functional
# 10240,functional
# 58631,non functional
# 51759,functional
# 10451,functional
# 1680,functional
# 58837,functional
# 26677,functional
# 33360,non functional
# 16390,functional
# 53822,non functional
# 1320,functional
# 53159,functional
# 35873,functional
# 67046,non functional
# 39292,functional
# 55236,non functional
# 7810,functional
# 70305,non functional
# 31485,functional needs repair
# 46501,functional
# 53670,functional
# 18666,non functional
# 24747,functional
# 188,functional
# 32525,functional needs repair
# 11620,non functional
# 31462,functional
# 32449,functional
# 12606,functional needs repair
# 50260,functional
# 43046,functional
# 61411,non functional
# 57545,functional
# 26024,non functional
# 65591,functional
# 2338,functional
# 6568,non functional
# 66489,functional
# 955,functional
# 4901,functional
# 29918,functional
# 59033,functional
# 15419,functional
# 50697,functional
# 15735,functional
# 68046,functional
# 32587,non functional
# 29620,non functional
# 71148,non functional
# 42965,functional
# 60594,functional
# 7569,non functional
# 7181,non functional
# 53810,functional
# 39814,functional
# 8777,non functional
# 13975,non functional
# 58025,functional
# 40433,non functional
# 23502,non functional
# 4719,non functional
# 36258,non functional
# 56110,functional
# 56055,functional
# 3310,non functional
# 70170,non functional
# 47013,functional
# 25407,functional
# 68954,non functional
# 34563,functional
# 63754,non functional
# 45483,functional
# 43435,functional
# 15087,functional
# 41666,functional
# 44817,functional
# 56284,functional
# 59408,functional
# 42029,functional
# 62750,functional
# 43865,non functional
# 63974,functional
# 60798,functional
# 49768,non functional
# 19138,functional
# 15870,non functional
# 31318,functional
# 67696,functional
# 47688,functional needs repair
# 54254,functional
# 7444,functional needs repair
# 44459,functional
# 53976,functional
# 70101,functional
# 25002,non functional
# 27243,functional
# 72115,functional
# 57830,functional
# 11301,functional
# 752,functional
# 13566,functional
# 42897,non functional
# 8009,functional
# 23807,non functional
# 43824,functional
# 46427,non functional
# 48957,non functional
# 43721,non functional
# 18464,functional needs repair
# 37729,functional
# 61771,functional
# 42365,functional
# 31266,non functional
# 6783,functional
# 23027,functional
# 19100,functional
# 19602,functional
# 66388,functional
# 69871,functional
# 56280,non functional
# 46737,non functional
# 48582,non functional
# 35153,non functional
# 11867,functional
# 48966,functional
# 58063,functional
# 7465,functional
# 61209,non functional
# 53603,functional
# 17532,functional
# 6669,functional
# 30594,functional
# 68559,functional
# 54311,non functional
# 21566,non functional
# 58614,non functional
# 26250,non functional
# 36357,non functional
# 45805,functional
# 14034,non functional
# 47789,non functional
# 16907,functional
# 18471,non functional
# 51608,non functional
# 46387,functional
# 34495,functional
# 25024,functional
# 15997,non functional
# 8590,non functional
# 37704,non functional
# 71242,functional
# 66191,functional
# 16818,functional
# 833,non functional
# 21723,functional
# 73697,functional
# 11830,functional
# 64198,non functional
# 51555,non functional
# 2158,non functional
# 66551,non functional
# 58004,functional
# 56352,functional
# 55692,functional
# 67658,functional
# 54127,non functional
# 47689,functional
# 7494,non functional
# 9215,non functional
# 73515,functional
# 70123,non functional
# 7017,functional
# 41948,functional
# 13367,functional
# 56128,non functional
# 13364,functional
# 37281,non functional
# 38955,functional
# 44964,non functional
# 7063,functional
# 9207,non functional
# 46851,non functional
# 34457,functional
# 7565,non functional
# 62245,functional
# 904,non functional
# 61462,non functional
# 34841,non functional
# 66342,non functional
# 39805,functional
# 25256,functional
# 22661,functional
# 55789,functional
# 17006,functional needs repair
# 44184,non functional
# 46739,functional
# 17105,functional needs repair
# 48588,functional
# 8383,non functional
# 35108,functional
# 25702,non functional
# 216,functional
# 51858,functional
# 51525,non functional
# 33424,functional
# 40171,non functional
# 59706,non functional
# 13273,non functional
# 4640,non functional
# 15589,non functional
# 67738,non functional
# 8663,non functional
# 50629,functional
# 70528,functional
# 36973,functional
# 16424,functional
# 16374,non functional
# 56271,functional
# 51690,functional
# 12954,functional
# 63750,non functional
# 39700,functional
# 35671,functional
# 1717,functional
# 69405,non functional
# 53562,functional
# 15810,functional
# 63417,non functional
# 52281,functional
# 44264,functional
# 48363,functional
# 42668,non functional
# 65699,non functional
# 24461,functional
# 1051,functional
# 1272,functional needs repair
# 9055,functional
# 48418,non functional
# 17133,functional
# 61176,functional
# 13633,non functional
# 60827,functional
# 12657,non functional
# 12181,non functional
# 69153,functional
# 14035,functional
# 44137,functional
# 31093,functional
# 30780,non functional
# 19757,non functional
# 37301,non functional
# 23880,functional
# 22366,functional
# 17408,non functional
# 22443,non functional
# 4844,non functional
# 44626,non functional
# 47616,functional
# 56174,non functional
# 41111,non functional
# 65912,functional
# 46900,functional
# 59905,functional
# 8544,functional
# 35270,functional
# 60082,functional
# 39830,non functional
# 66566,non functional
# 17798,functional
# 22537,non functional
# 39196,non functional
# 57348,functional needs repair
# 7954,functional
# 45278,non functional
# 22127,functional
# 15447,functional
# 69428,functional
# 68152,non functional
# 899,non functional
# 55433,non functional
# 32859,functional
# 48230,non functional
# 49451,non functional
# 4371,functional
# 36252,functional
# 2459,non functional
# 50494,functional
# 8542,non functional
# 28294,functional
# 1290,functional
# 25117,functional
# 31880,functional
# 59021,functional
# 52658,functional
# 53387,functional
# 43999,non functional
# 18620,non functional
# 16766,non functional
# 20062,non functional
# 6046,functional
# 47640,functional
# 65625,functional
# 60404,functional
# 30797,non functional
# 27394,functional needs repair
# 58382,functional
# 26222,functional
# 3105,non functional
# 33332,functional
# 31381,non functional
# 62291,non functional
# 59256,functional
# 1878,functional
# 41661,functional
# 62360,functional
# 71825,functional
# 44440,functional
# 42899,functional
# 55652,non functional
# 26674,non functional
# 8508,functional
# 52316,functional
# 14280,non functional
# 61322,functional
# 53323,functional
# 28538,functional
# 46953,non functional
# 20339,functional
# 32276,functional
# 38296,non functional
# 16864,functional
# 69161,non functional
# 48613,functional
# 30510,non functional
# 30194,functional
# 61052,functional
# 58656,non functional
# 55757,non functional
# 21717,non functional
# 5832,functional
# 54580,functional
# 63540,non functional
# 57665,functional
# 21491,functional
# 65846,non functional
# 61344,non functional
# 23080,non functional
# 26709,functional
# 43982,functional needs repair
# 11728,functional
# 41653,functional needs repair
# 19316,functional
# 12455,functional
# 10081,functional
# 63295,non functional
# 28465,non functional
# 66154,functional
# 19678,functional
# 11657,functional
# 73866,functional
# 73388,non functional
# 9913,functional
# 4378,non functional
# 8897,non functional
# 34534,functional
# 15834,functional needs repair
# 15482,non functional
# 57373,functional
# 2797,functional
# 9642,functional
# 9840,non functional
# 11789,functional
# 8930,functional
# 59431,functional
# 41955,non functional
# 23955,functional
# 40219,non functional
# 19114,functional
# 27231,functional
# 51384,functional
# 59970,functional
# 14377,non functional
# 28876,non functional
# 10215,functional
# 70796,functional
# 56815,functional
# 51927,functional
# 20645,non functional
# 15216,functional
# 29019,non functional
# 37375,non functional
# 41382,non functional
# 20971,functional
# 762,functional
# 29080,functional
# 60401,functional
# 914,functional
# 31009,non functional
# 71643,functional
# 28800,functional needs repair
# 41377,non functional
# 50170,functional
# 59465,non functional
# 7315,functional
# 37788,non functional
# 68953,functional
# 33466,functional
# 44619,functional
# 43358,functional
# 14720,functional
# 14031,non functional
# 2271,non functional
# 12512,functional
# 10346,functional
# 73475,non functional
# 26244,functional
# 56593,functional
# 4350,functional
# 7913,functional
# 60069,functional
# 33071,functional
# 14312,functional
# 50353,functional
# 19732,non functional
# 38551,non functional
# 49730,functional
# 56377,functional
# 31723,functional needs repair
# 5151,functional
# 14718,non functional
# 39359,non functional
# 48728,functional
# 27624,functional
# 18069,functional
# 52066,non functional
# 69831,non functional
# 8835,functional
# 72757,functional
# 60696,functional
# 33680,functional
# 30454,functional
# 57671,non functional
# 13503,non functional
# 34837,functional
# 33516,non functional
# 34824,functional
# 101,functional
# 2017,functional
# 52375,non functional
# 73439,functional
# 17950,functional
# 71886,functional
# 61278,functional
# 57776,functional
# 44064,functional
# 48502,non functional
# 32759,functional
# 57195,non functional
# 35259,functional
# 3955,functional
# 50215,functional
# 9425,functional
# 68556,functional
# 23610,functional
# 13392,functional
# 56579,functional
# 42434,functional
# 73364,non functional
# 73643,functional
# 61837,non functional
# 44405,functional
# 10193,functional
# 55176,functional
# 20983,non functional
# 65551,functional
# 47258,functional
# 27421,non functional
# 70590,functional
# 2087,non functional
# 11170,functional
# 8698,non functional
# 13260,functional
# 56082,functional
# 48891,functional
# 55422,non functional
# 22623,non functional
# 46580,functional
# 36648,functional
# 14487,functional
# 3269,non functional
# 7922,functional
# 4293,non functional
# 22388,functional
# 12997,functional
# 31426,functional
# 358,non functional
# 73197,non functional
# 40649,functional
# 47948,functional
# 56401,functional
# 23718,non functional
# 56713,non functional
# 10205,non functional
# 59505,functional
# 52255,functional
# 27601,functional
# 44895,functional needs repair
# 68027,non functional
# 42839,functional
# 44822,functional
# 33184,functional
# 34842,functional
# 48948,non functional
# 16141,non functional
# 17762,non functional
# 27416,functional
# 35992,functional
# 42825,functional
# 12363,non functional
# 41971,functional
# 44737,non functional
# 69191,functional
# 33893,functional
# 39538,functional
# 46544,functional
# 37347,non functional
# 7504,functional
# 71022,non functional
# 31833,functional
# 53772,functional
# 51268,functional
# 65296,functional
# 49042,non functional
# 29120,functional
# 47336,functional needs repair
# 47648,non functional
# 69564,functional
# 34129,non functional
# 5055,non functional
# 19694,functional
# 55640,functional
# 70737,non functional
# 28345,functional
# 43303,functional
# 2811,functional
# 14735,non functional
# 48047,functional
# 17852,functional
# 8479,non functional
# 15994,non functional
# 73255,functional
# 6867,functional
# 4728,functional
# 13241,functional
# 56279,non functional
# 64526,functional
# 67119,non functional
# 33700,non functional
# 19744,functional
# 56000,non functional
# 35480,non functional
# 43653,non functional
# 49339,functional needs repair
# 57344,functional
# 49524,functional
# 50846,functional
# 63024,functional
# 57153,non functional
# 61040,functional
# 36768,non functional
# 68255,non functional
# 21152,non functional
# 32023,functional
# 26494,non functional
# 55396,functional needs repair
# 6656,functional
# 15613,functional
# 33427,non functional
# 66629,non functional
# 3741,functional
# 11818,functional
# 52726,functional
# 3541,functional
# 45994,non functional
# 20627,non functional
# 31369,functional
# 42898,functional
# 21882,functional
# 42582,functional
# 15496,functional
# 53708,non functional
# 50920,functional
# 10915,functional
# 51489,functional
# 56936,functional
# 17997,functional
# 14638,functional
# 51427,functional
# 31390,non functional
# 63645,functional
# 29313,non functional
# 33339,functional needs repair
# 1252,functional
# 73579,non functional
# 52228,functional
# 70038,functional
# 25901,functional
# 26580,non functional
# 66059,non functional
# 32944,functional
# 13686,functional
# 8471,functional
# 19620,functional
# 74162,non functional
# 37994,functional
# 71151,functional
# 45017,functional
# 12592,functional
# 58693,functional
# 57539,functional
# 71252,non functional
# 7869,functional
# 57316,functional
# 59757,functional
# 64579,functional
# 57731,functional
# 65541,functional
# 68174,functional
# 39307,non functional
# 18990,functional
# 28749,functional
# 33492,functional
# 68707,non functional

# %%
print(output_for_submission.status_group.value_counts())
print(output_for_submission.shape)
# Out:
# functional                 9578
# non functional             4484
# functional needs repair     296
# Name: status_group, dtype: int64
# (14358, 2)
